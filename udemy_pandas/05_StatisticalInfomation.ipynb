# %%
# https://www.udemy.com/course/python-for-machine-learning-data-science-masterclass/learn/lecture/22971400#overview

https://kodekloud.com/topic/practice-test-replicasets-2/

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./datas/test.csv')
df.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
df.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   418.000000  418.000000  332.000000  418.000000  418.000000  417.000000
# mean   1100.500000    2.265550   30.272590    0.447368    0.392344   35.627188
# std     120.810458    0.841838   14.181209    0.896760    0.981429   55.907576
# min     892.000000    1.000000    0.170000    0.000000    0.000000    0.000000
# 25%     996.250000    1.000000   21.000000    0.000000    0.000000    7.895800
# 50%    1100.500000    3.000000   27.000000    0.000000    0.000000   14.454200
# 75%    1204.750000    3.000000   39.000000    1.000000    0.000000   31.500000
# max    1309.000000    3.000000   76.000000    8.000000    9.000000  512.329200

# %%
df.sort_values(by = 'Age', ascending=False)
# Out:
#      PassengerId  Pclass                                               Name  \
# 96           988       1  Cavendish, Mrs. Tyrell William (Julia Florence...
# 81           973       1                                 Straus, Mr. Isidor
# 236         1128       1                           Warren, Mr. Frank Manley
# 305         1197       1  Crosby, Mrs. Edward Gifford (Catherine Elizabe...
# 179         1071       1  Compton, Mrs. Alexander Taylor (Mary Eliza Ing...
# ..           ...     ...                                                ...
# 408         1300       3                    Riordan, Miss. Johanna Hannah""
# 410         1302       3                             Naughton, Miss. Hannah
# 413         1305       3                                 Spector, Mr. Woolf
# 416         1308       3                                Ware, Mr. Frederick
# 417         1309       3                           Peter, Master. Michael J
#
# ...

# %%
df.sort_values(['Age', 'Fare'])
# Out:
#      PassengerId  Pclass                                     Name     Sex  \
# 354         1246       3  Dean, Miss. Elizabeth Gladys Millvina""  female
# 201         1093       3  Danbom, Master. Gilbert Sigvard Emanuel    male
# 281         1173       3           Peacock, Master. Alfred Edward    male
# 307         1199       3                Aks, Master. Philip Frank    male
# 250         1142       2                    West, Miss. Barbara J  female
# ..           ...     ...                                      ...     ...
# 146         1038       1              Hilliard, Mr. Herbert Henry    male
# 39           931       3                            Hee, Mr. Ling    male
# 188         1080       3                          Sage, Miss. Ada  female
# 342         1234       3                    Sage, Mr. John George    male
# 365         1257       3           Sage, Mrs. John (Annie Bullen)  female
#
#       Age  SibSp  Parch              Ticket     Fare Cabin Embarked
# ...

# %%
df['Fare'].max()
# Out:
# 512.3292

# %%
df['Fare'].idxmax()
# Out:
# 343

# %%
df.iloc[343]
# Out:
# PassengerId                                                 1235
# Pclass                                                         1
# Name           Cardeza, Mrs. James Warburton Martinez (Charlo...
# Sex                                                       female
# Age                                                         58.0
# SibSp                                                          0
# Parch                                                          1
# Ticket                                                  PC 17755
# Fare                                                    512.3292
# Cabin                                                B51 B53 B55
# Embarked                                                       C
# Name: 343, dtype: object

# %%
df['Fare'].min()
# Out:
# 0.0

# %%
df['Fare'].idxmin()
# Out:
# 266

# %%
df.iloc[266]
# Out:
# PassengerId                                     1158
# Pclass                                             1
# Name           Chisholm, Mr. Roderick Robert Crispin
# Sex                                             male
# Age                                              NaN
# SibSp                                              0
# Parch                                              0
# Ticket                                        112051
# Fare                                             0.0
# Cabin                                            NaN
# Embarked                                           S
# Name: 266, dtype: object

# %%
df.corr()
# Out:
#              PassengerId    Pclass       Age     SibSp     Parch      Fare
# PassengerId     1.000000 -0.026751 -0.034102  0.003818  0.043080  0.008211
# Pclass         -0.026751  1.000000 -0.492143  0.001087  0.018721 -0.577147
# Age            -0.034102 -0.492143  1.000000 -0.091587 -0.061249  0.337932
# SibSp           0.003818  0.001087 -0.091587  1.000000  0.306895  0.171539
# Parch           0.043080  0.018721 -0.061249  0.306895  1.000000  0.230046
# Fare            0.008211 -0.577147  0.337932  0.171539  0.230046  1.000000

# %%
df['Sex'].value_counts()
# Out:
# male      266
# female    152
# Name: Sex, dtype: int64

# %%
df.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
df['Pclass'].unique()
# Out:
# array([3, 2, 1])

# %%
len(df['Ticket'].unique())
# Out:
# 363

# %%
df['Sex'].replace(['female', 'male'], ['F', 'M'])
# Out:
# 0      M
# 1      F
# 2      M
# 3      M
# 4      F
#       ..
# 413    M
# 414    F
# 415    M
# 416    M
# 417    M
# Name: Sex, Length: 418, dtype: object

# %%
map_sex = {'female':'F', 'male':'M'}
df['Sex'].map(map_sex)
# Out:
# 0      M
# 1      F
# 2      M
# 3      M
# 4      F
#       ..
# 413    M
# 414    F
# 415    M
# 416    M
# 417    M
# Name: Sex, Length: 418, dtype: object

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 413    False
# 414    False
# 415    False
# 416    False
# 417    False
# Length: 418, dtype: bool

# %%
df.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
simple_df = pd.DataFrame([1, 2, 2], ['a', 'b', 'c'])
simple_df
# Out:
#    0
# a  1
# b  2
# c  2

# %%
simple_df.duplicated()
# Out:
# a    False
# b    False
# c     True
# dtype: bool

# %%
simple_df = pd.DataFrame([1, 2, 2, 2], ['a', 'b', 'c', 'd'])
simple_df.duplicated()
# Out:
# a    False
# b    False
# c     True
# d     True
# dtype: bool

# %%
simple_df.drop_duplicates()
# Out:
#    0
# a  1
# b  2

# %%
df[df['Age'].between(20, 30, inclusive = True)]
# Out:
# /var/folders/7w/k23qswcd04z8925pqjt296rw0000gp/T/ipykernel_8362/704745157.py:1: FutureWarning: Boolean inputs to the `inclusive` argument are deprecated infavour of `both` or `neither`.
#   df[df['Age'].between(20, 30, inclusive = True)]
#      PassengerId  Pclass                                          Name  \
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 6            898       3                          Connolly, Miss. Kate
# 7            899       2                  Caldwell, Mr. Albert Francis
# 9            901       3                       Davies, Mr. John Samuel
# ..           ...     ...                                           ...
# 400         1292       1                       Bonnell, Miss. Caroline
# 402         1294       1                Gibson, Miss. Dorothy Winifred
# 405         1297       2  Nourney, Mr. Alfred (Baron von Drachstedt")"
# ...

# %%
df.nlargest(2, 'Age')
# Out:
#     PassengerId  Pclass                                               Name  \
# 96          988       1  Cavendish, Mrs. Tyrell William (Julia Florence...
# 81          973       1                                 Straus, Mr. Isidor
#
#        Sex   Age  SibSp  Parch    Ticket      Fare    Cabin Embarked
# 96  female  76.0      1      0     19877   78.8500      C46        S
# 81    male  67.0      1      0  PC 17483  221.7792  C55 C57        S

# %%
df.sort_values('Age', ascending=False).iloc[0:2]
# Out:
#     PassengerId  Pclass                                               Name  \
# 96          988       1  Cavendish, Mrs. Tyrell William (Julia Florence...
# 81          973       1                                 Straus, Mr. Isidor
#
#        Sex   Age  SibSp  Parch    Ticket      Fare    Cabin Embarked
# 96  female  76.0      1      0     19877   78.8500      C46        S
# 81    male  67.0      1      0  PC 17483  221.7792  C55 C57        S

# %%
df.nsmallest(2, 'Age')
# Out:
#      PassengerId  Pclass                                     Name     Sex  \
# 354         1246       3  Dean, Miss. Elizabeth Gladys Millvina""  female
# 201         1093       3  Danbom, Master. Gilbert Sigvard Emanuel    male
#
#       Age  SibSp  Parch     Ticket    Fare Cabin Embarked
# 354  0.17      1      2  C.A. 2315  20.575   NaN        S
# 201  0.33      0      2     347080  14.400   NaN        S

# %%
df.sort_values('Age', ascending=True).iloc[0:2]
# Out:
#      PassengerId  Pclass                                     Name     Sex  \
# 354         1246       3  Dean, Miss. Elizabeth Gladys Millvina""  female
# 201         1093       3  Danbom, Master. Gilbert Sigvard Emanuel    male
#
#       Age  SibSp  Parch     Ticket    Fare Cabin Embarked
# 354  0.17      1      2  C.A. 2315  20.575   NaN        S
# 201  0.33      0      2     347080  14.400   NaN        S

# %%
df.sample(5)
# Out:
#      PassengerId  Pclass                                               Name  \
# 190         1082       2                               Angle, Mr. William A
# 65           957       2  Corey, Mrs. Percy C (Mary Phyllis Elizabeth Mi...
# 315         1207       3                               Hagardon, Miss. Kate
# 345         1237       3                        Abelseth, Miss. Karen Marie
# 209         1101       3                                 Delalic, Mr. Redjo
#
#         Sex   Age  SibSp  Parch        Ticket     Fare Cabin Embarked
# 190    male  34.0      1      0        226875  26.0000   NaN        S
# 65   female   NaN      0      0  F.C.C. 13534  21.0000   NaN        S
# 315  female  17.0      0      0   AQ/3. 30631   7.7333   NaN        Q
# 345  female  16.0      0      0        348125   7.6500   NaN        S
# 209    male  25.0      0      0        349250   7.8958   NaN        S

# %%
df.sample(frac=0.1) # 10퍼센트 데이터 추출
# Out:
#      PassengerId  Pclass                                              Name  \
# 342         1234       3                             Sage, Mr. John George
# 235         1127       3                            Vendel, Mr. Olof Edvin
# 315         1207       3                              Hagardon, Miss. Kate
# 118         1010       1                              Beattie, Mr. Thomson
# 300         1192       3                         Olsson, Mr. Oscar Wilhelm
# 176         1068       2                              Sincock, Miss. Maude
# 282         1174       3                             Fleming, Miss. Honora
# 380         1272       3                             O'Connor, Mr. Patrick
# 331         1223       1                      Dulles, Mr. William Crothers
# 280         1172       3                            Oreskovic, Miss. Jelka
# 233         1125       3                              Linehan, Mr. Michael
# ...
